# %%
import pandas as pd
df = pd.read_csv('insurance_data.csv')
df.head()
# Out:
#    age  bought_insurance
# 0   22                 0
# 1   25                 0
# 2   47                 1
# 3   52                 0
# 4   46                 1

# %%
from sklearn.linear_model import LinearRegression
reg = LinearRegression()

# %%
reg.fit(df[['age']], df.bought_insurance)
# Out:
# LinearRegression()

# %%
from matplotlib import pyplot as plt
plt.scatter(df['age'], df['bought_insurance'])
plt.plot(df['age'], reg.predict(df[['age']]), color = 'blue')

# %%
# rather than this linear regression, logistic regression will be best suited

# %%
X = df[['age']]
y = df.bought_insurance

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.2)

# %%
X_test
# Out:
#     age
# 11   28
# 19   18
# 15   55
# 8    62
# 10   18
# 5    56

# %%
from sklearn.linear_model import LogisticRegression
reg = LogisticRegression()

# %%
reg.fit(X_train, y_train)
# Out:
# LogisticRegression()

# %%
reg.predict(X_test)
# Out:
# array([0, 0, 1, 1, 0, 1], dtype=int64)

# %%
y_test
# Out:
# 11    0
# 19    0
# 15    1
# 8     1
# 10    0
# 5     1
# Name: bought_insurance, dtype: int64

# %%
reg.score(X,y)
# Out:
# 0.8888888888888888

# %%
reg.predict_proba(X_test)
# Out:
# array([[0.77300681, 0.22699319],
#        [0.91594367, 0.08405633],
#        [0.12841999, 0.87158001],
#        [0.0612738 , 0.9387262 ],
#        [0.91594367, 0.08405633],
#        [0.1159544 , 0.8840456 ]])
